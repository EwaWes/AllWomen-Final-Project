# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Library-imports" data-toc-modified-id="Library-imports-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Library imports</a></span></li><li><span><a href="#Function-to-extract-data" data-toc-modified-id="Function-to-extract-data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Function to extract data</a></span></li><li><span><a href="#Collecting-data-from-Eurostat" data-toc-modified-id="Collecting-data-from-Eurostat-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Collecting data from Eurostat</a></span><ul class="toc-item"><li><span><a href="#Obesity-rate-by-body-mass-index-(BMI)" data-toc-modified-id="Obesity-rate-by-body-mass-index-(BMI)-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Obesity rate by body mass index (BMI)</a></span><ul class="toc-item"><li><span><a href="#Variables:-obestity_rate_2014-(18-entries),-obestity_rate_2019-(31-entries)" data-toc-modified-id="Variables:-obestity_rate_2014-(18-entries),-obestity_rate_2019-(31-entries)-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Variables: obestity_rate_2014 (18 entries), obestity_rate_2019 (31 entries)</a></span></li></ul></li><li><span><a href="#People-at-risk-of-poverty-or-social-exclusion" data-toc-modified-id="People-at-risk-of-poverty-or-social-exclusion-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>People at risk of poverty or social exclusion</a></span><ul class="toc-item"><li><span><a href="#Variables:-people_risk_poverty_2015,-people_risk_poverty_2019" data-toc-modified-id="Variables:-people_risk_poverty_2015,-people_risk_poverty_2019-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Variables: people_risk_poverty_2015, people_risk_poverty_2019</a></span></li></ul></li><li><span><a href="#The-real-gross-disposable-income-of-households-per-capita-(index-=-2008)" data-toc-modified-id="The-real-gross-disposable-income-of-households-per-capita-(index-=-2008)-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>The real gross disposable income of households per capita (index = 2008)</a></span><ul class="toc-item"><li><span><a href="#Variables:-gross_disposable_income_2014,-gross_disposable_income_2019" data-toc-modified-id="Variables:-gross_disposable_income_2014,-gross_disposable_income_2019-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Variables: gross_disposable_income_2014, gross_disposable_income_2019</a></span></li></ul></li><li><span><a href="#Persons-reporting-a-chronic-disease,-by-disease" data-toc-modified-id="Persons-reporting-a-chronic-disease,-by-disease-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Persons reporting a chronic disease, by disease</a></span><ul class="toc-item"><li><span><a href="#Variables:-asthma_2019,-CHR_LW_RES_2019,-DIAB_2019,-DPR_CHR_2019,-HBLPR_2019" data-toc-modified-id="Variables:-asthma_2019,-CHR_LW_RES_2019,-DIAB_2019,-DPR_CHR_2019,-HBLPR_2019-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Variables: asthma_2019, CHR_LW_RES_2019, DIAB_2019, DPR_CHR_2019, HBLPR_2019</a></span></li></ul></li><li><span><a href="#Daily-consumption-of-fruit-and-vegetables" data-toc-modified-id="Daily-consumption-of-fruit-and-vegetables-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Daily consumption of fruit and vegetables</a></span><ul class="toc-item"><li><span><a href="#Variables:-fruit_0,-fruit_1_4,-fruit_5" data-toc-modified-id="Variables:-fruit_0,-fruit_1_4,-fruit_5-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Variables: fruit_0, fruit_1_4, fruit_5</a></span></li></ul></li><li><span><a href="#Deaths-(total)---csv-downloaded,-but-data-not-loaded" data-toc-modified-id="Deaths-(total)---csv-downloaded,-but-data-not-loaded-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Deaths (total) - csv downloaded, but data not loaded</a></span></li><li><span><a href="#Life-expectancy" data-toc-modified-id="Life-expectancy-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Life expectancy</a></span><ul class="toc-item"><li><span><a href="#Variables:-life_exp_2015,-life_exp_2019" data-toc-modified-id="Variables:-life_exp_2015,-life_exp_2019-3.7.1"><span class="toc-item-num">3.7.1&nbsp;&nbsp;</span>Variables: life_exp_2015, life_exp_2019</a></span></li></ul></li><li><span><a href="#Gross-domestic-product-(GDP)-at-current-market-prices" data-toc-modified-id="Gross-domestic-product-(GDP)-at-current-market-prices-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Gross domestic product (GDP) at current market prices</a></span><ul class="toc-item"><li><span><a href="#Varilables:-GDP_2014,-GDP_2019" data-toc-modified-id="Varilables:-GDP_2014,-GDP_2019-3.8.1"><span class="toc-item-num">3.8.1&nbsp;&nbsp;</span>Varilables: GDP_2014, GDP_2019</a></span></li></ul></li><li><span><a href="#crude-death-rate" data-toc-modified-id="crude-death-rate-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>crude death rate</a></span><ul class="toc-item"><li><span><a href="#Variables:-crude_death_rate_2014,-crude_death_rate_2018" data-toc-modified-id="Variables:-crude_death_rate_2014,-crude_death_rate_2018-3.9.1"><span class="toc-item-num">3.9.1&nbsp;&nbsp;</span>Variables: crude_death_rate_2014, crude_death_rate_2018</a></span></li></ul></li><li><span><a href="#Infant-mortality-rates" data-toc-modified-id="Infant-mortality-rates-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Infant mortality rates</a></span><ul class="toc-item"><li><span><a href="#Variables:-inf_mort_2014,-inf_mort_2019" data-toc-modified-id="Variables:-inf_mort_2014,-inf_mort_2019-3.10.1"><span class="toc-item-num">3.10.1&nbsp;&nbsp;</span>Variables: inf_mort_2014, inf_mort_2019</a></span></li></ul></li><li><span><a href="#Healthy-life-years" data-toc-modified-id="Healthy-life-years-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>Healthy life years</a></span><ul class="toc-item"><li><span><a href="#Variables:-healthy_years_2014,-healthy_years_2019" data-toc-modified-id="Variables:-healthy_years_2014,-healthy_years_2019-3.11.1"><span class="toc-item-num">3.11.1&nbsp;&nbsp;</span>Variables: healthy_years_2014, healthy_years_2019</a></span></li></ul></li><li><span><a href="#Health-care-expenditure,-unit-of-measure:-euro-per-inhabitant" data-toc-modified-id="Health-care-expenditure,-unit-of-measure:-euro-per-inhabitant-3.12"><span class="toc-item-num">3.12&nbsp;&nbsp;</span>Health care expenditure, unit of measure: euro per inhabitant</a></span><ul class="toc-item"><li><span><a href="#Variables:-health_exp_2014,-health_exp_2019" data-toc-modified-id="Variables:-health_exp_2014,-health_exp_2019-3.12.1"><span class="toc-item-num">3.12.1&nbsp;&nbsp;</span>Variables: health_exp_2014, health_exp_2019</a></span></li></ul></li><li><span><a href="#Health-personnel-(excluding-nursing-and-caring-professionals)-Per-hundred-thousand-inhabitants" data-toc-modified-id="Health-personnel-(excluding-nursing-and-caring-professionals)-Per-hundred-thousand-inhabitants-3.13"><span class="toc-item-num">3.13&nbsp;&nbsp;</span>Health personnel (excluding nursing and caring professionals) Per hundred thousand inhabitants</a></span><ul class="toc-item"><li><span><a href="#Variables:-personnel_2014,-personnel_2018" data-toc-modified-id="Variables:-personnel_2014,-personnel_2018-3.13.1"><span class="toc-item-num">3.13.1&nbsp;&nbsp;</span>Variables: personnel_2014, personnel_2018</a></span></li></ul></li><li><span><a href="#Hospital-beds-Per-hundred-thousand-inhabitants" data-toc-modified-id="Hospital-beds-Per-hundred-thousand-inhabitants-3.14"><span class="toc-item-num">3.14&nbsp;&nbsp;</span>Hospital beds Per hundred thousand inhabitants</a></span><ul class="toc-item"><li><span><a href="#Variables:-hosp_beds2014,-hosp_beds2018" data-toc-modified-id="Variables:-hosp_beds2014,-hosp_beds2018-3.14.1"><span class="toc-item-num">3.14.1&nbsp;&nbsp;</span>Variables: hosp_beds2014, hosp_beds2018</a></span></li></ul></li><li><span><a href="#Employment-rate-by-sex" data-toc-modified-id="Employment-rate-by-sex-3.15"><span class="toc-item-num">3.15&nbsp;&nbsp;</span>Employment rate by sex</a></span><ul class="toc-item"><li><span><a href="#Variable:-unempl2019" data-toc-modified-id="Variable:-unempl2019-3.15.1"><span class="toc-item-num">3.15.1&nbsp;&nbsp;</span>Variable: unempl2019</a></span></li></ul></li><li><span><a href="#Households-with-access-to-the-internet-at-home" data-toc-modified-id="Households-with-access-to-the-internet-at-home-3.16"><span class="toc-item-num">3.16&nbsp;&nbsp;</span>Households with access to the internet at home</a></span><ul class="toc-item"><li><span><a href="#Variables-=-internet2019" data-toc-modified-id="Variables-=-internet2019-3.16.1"><span class="toc-item-num">3.16.1&nbsp;&nbsp;</span>Variables = internet2019</a></span></li></ul></li><li><span><a href="#Young-people-neither-in-employment-nor-in-education-and-training" data-toc-modified-id="Young-people-neither-in-employment-nor-in-education-and-training-3.17"><span class="toc-item-num">3.17&nbsp;&nbsp;</span>Young people neither in employment nor in education and training</a></span><ul class="toc-item"><li><span><a href="#Variables:-no_job_no_edu" data-toc-modified-id="Variables:-no_job_no_edu-3.17.1"><span class="toc-item-num">3.17.1&nbsp;&nbsp;</span>Variables: no_job_no_edu</a></span></li></ul></li><li><span><a href="#Mean-and-median-income-(in-cities,-in-euro)" data-toc-modified-id="Mean-and-median-income-(in-cities,-in-euro)-3.18"><span class="toc-item-num">3.18&nbsp;&nbsp;</span>Mean and median income (in cities, in euro)</a></span><ul class="toc-item"><li><span><a href="#Variables:-income2019" data-toc-modified-id="Variables:-income2019-3.18.1"><span class="toc-item-num">3.18.1&nbsp;&nbsp;</span>Variables: income2019</a></span></li></ul></li></ul></li><li><span><a href="#Creating-health-situation-before-covid" data-toc-modified-id="Creating-health-situation-before-covid-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Creating health situation before covid</a></span><ul class="toc-item"><li><span><a href="#Droping-rows-that-have-at-least-70-%-na" data-toc-modified-id="Droping-rows-that-have-at-least-70-%-na-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Droping rows that have at least 70 % na</a></span></li></ul></li><li><span><a href="#Target-data:-excess-deaths" data-toc-modified-id="Target-data:-excess-deaths-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Target data: excess deaths</a></span></li><li><span><a href="#Master-dataframe" data-toc-modified-id="Master-dataframe-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Master dataframe</a></span></li></ul></div>

# %% [markdown]
# 1. Collect data from Eurostat:
#
#     - GDP
#
#     - spending on healthcare
#
#     - workers in healthcare
#
#     - extra mortality
#
#     - life expectancy
#
#     - ...
#
# 2. Combine into one dataset
#
# 3. Scale datat
#
# 4. Clustering
#
# In this case n=13 samples and p=22 variables, i.e., n<p. In the ideal case n should be greater than p. But cluster analysis is an exploratory technique and you can apply it anyway. First, you can apply a nonhierarchical cluster analysis (for example, Ward) to get the dendrogram and identify the number of K clusters. Next, you should apply KMeans with K cluster, where K was identified previously. Use the following R commands:
# resulthc = hclust(dist(data),method='ward.D2',members=NULL) # ward method
# plot(resulthc) # to make dendrogram
# resultkmeans = kmeans(data,centers=K,iter.max=100,nstart=10) # KMeans with K clusters
# resultkmeans$cluster # to see the cluster of each observation
#
# 5. PCA to visualize clustering (2D or 3D)

# %% [markdown]
# # Library imports

# %%
import pandas as pd

# %%
from functools import reduce

# %% [markdown]
# # Function to extract data

# %%
'''def read_file(path): 
    a = pd.read_csv(path)
    return a'''
# Out:
# 'def read_file(path): \n    a = pd.read_csv(path)\n    return a'

# %%
'''def get_data(dataframe, col_start, col_end):
    new_dataframe = dataframe.iloc[:,col_start: col_end+1]
    return new_dataframe'''
# Out:
# 'def get_data(dataframe, col_start, col_end):\n    new_dataframe = dataframe.iloc[:,col_start: col_end+1]\n    return new_dataframe'

# %%
#trial = read_file(path)

# %%
#trial2 = get_data(trial, 5, 8)

# %%
'''def divide_by_year(dataframe,year):
    new_data = [dataframe['TIME_PERIOD'] == year]
    #.rename(columns = {'OBS_VALUE': str(col_name)+str(year)})
    return new_data'''
# Out:
# "def divide_by_year(dataframe,year):\n    new_data = [dataframe['TIME_PERIOD'] == year]\n    #.rename(columns = {'OBS_VALUE': str(col_name)+str(year)})\n    return new_data"

# %%
#trial_2017 = divide_by_year(trial2,2008)

# %% [markdown]
# # Collecting data from Eurostat

# %% [markdown]
# ## Obesity rate by body mass index (BMI)
#
# The indicator measures the share of obese people based on their body mass index (BMI). BMI is defined as the weight in kilos divided by the square of the height in meters. People aged 18 years or over are considered obese with a BMI equal or greater than 30. Other categories are: underweight (BMI less than 18.5), normal weight (BMI between 18.5 and less than 25), and pre-obese (BMI between 25 and less than 30). The category overweight (BMI equal or greater than 25) combines the two categories pre-obese and obese.

# %%
obesity_rate = pd.read_csv('/Users/ewawesolowska/Documents/Data_Analytics/Final project/EU_obesity_rate.csv')

# %%
obesity_rate
# Out:
#                  DATAFLOW        LAST UPDATE freq unit       bmi geo  \
# 0    ESTAT:SDG_02_10(1.0)  22/10/21 23:00:00    A   PC  BMI_GE25  AT
# 1    ESTAT:SDG_02_10(1.0)  22/10/21 23:00:00    A   PC  BMI_GE25  AT
# 2    ESTAT:SDG_02_10(1.0)  22/10/21 23:00:00    A   PC  BMI_GE25  AT
# 3    ESTAT:SDG_02_10(1.0)  22/10/21 23:00:00    A   PC  BMI_GE25  AT
# 4    ESTAT:SDG_02_10(1.0)  22/10/21 23:00:00    A   PC  BMI_GE25  BE
# ..                    ...                ...  ...  ...       ...  ..
# 108  ESTAT:SDG_02_10(1.0)  22/10/21 23:00:00    A   PC  BMI_GE25  TR
# 109  ESTAT:SDG_02_10(1.0)  22/10/21 23:00:00    A   PC  BMI_GE25  TR
# 110  ESTAT:SDG_02_10(1.0)  22/10/21 23:00:00    A   PC  BMI_GE25  TR
# 111  ESTAT:SDG_02_10(1.0)  22/10/21 23:00:00    A   PC  BMI_GE25  UK
# 112  ESTAT:SDG_02_10(1.0)  22/10/21 23:00:00    A   PC  BMI_GE25  UK
#
#      TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0           2008       49.3      NaN
# 1           2014       48.0      NaN
# ...

# %%
#Selecting columns of interest
obesity_rate = obesity_rate.iloc[:,5:8]

# %%
obestity_rate_2014 = obesity_rate[obesity_rate.TIME_PERIOD == 2014].rename(columns = {'OBS_VALUE': "Obesity_2014"}).drop(columns = 'TIME_PERIOD')

# %%
obestity_rate_2019 = obesity_rate[obesity_rate.TIME_PERIOD == 2019].rename(columns = {'OBS_VALUE': "Obesity_2019"}).drop(columns = 'TIME_PERIOD')

# %% [markdown]
# ### Variables: obestity_rate_2014 (18 entries), obestity_rate_2019 (31 entries)

# %% [markdown]
# ## People at risk of poverty or social exclusion
#
# This indicator corresponds to the sum of persons who are: at risk of poverty or severely materially or socially deprived or living in households with very low work intensity. Persons are only counted once even if they are present in several sub-indicators. At risk-of-poverty are persons with an equivalised disposable income below the risk-of-poverty threshold, which is set at 60 % of the national median equivalised disposable income (after social transfers). Severely materially or socially deprived persons have living conditions severely constrained by a lack of resources, they experience at least 7 out of 13 following deprivations items: cannot afford i) to pay rent or utility bills, ii) keep home adequately warm, iii) face unexpected expenses, iv) eat meat, fish or a protein equivalent every second day, v) a week holiday away from home, vi) have access to a car/van for personal use; vii) replace worn out furniture; viii) replace worn-out clothes with some new ones; ix) have two pairs of properly fitting shoes; x) spend a small amount of money each week on him/herself (“pocket money”); xi) have regular leisure activities; xii) get together with friends/family for a drink/meal at least once a month; and xiii) have an internet connection. People living in households with very low work intensity are those aged 0-64 living in households where the adults (aged 18-64) work 20% or less of their total work potential during the past year. The indicator is based on the EU-SILC (statistics on income, social inclusion and living conditions).

# %%
people_risk_poverty = pd.read_csv('/Users/ewawesolowska/Documents/Data_Analytics/Final project/People_at_risk_of_poverty.csv')

# %%
people_risk_poverty
# Out:
#                    DATAFLOW        LAST UPDATE freq sex    age unit geo  \
# 0    ESTAT:TEPSR_LM411(1.0)  22/10/21 23:00:00    A   T  TOTAL   PC  AL
# 1    ESTAT:TEPSR_LM411(1.0)  22/10/21 23:00:00    A   T  TOTAL   PC  AL
# 2    ESTAT:TEPSR_LM411(1.0)  22/10/21 23:00:00    A   T  TOTAL   PC  AL
# 3    ESTAT:TEPSR_LM411(1.0)  22/10/21 23:00:00    A   T  TOTAL   PC  AL
# 4    ESTAT:TEPSR_LM411(1.0)  22/10/21 23:00:00    A   T  TOTAL   PC  AT
# ..                      ...                ...  ...  ..    ...  ...  ..
# 221  ESTAT:TEPSR_LM411(1.0)  22/10/21 23:00:00    A   T  TOTAL   PC  TR
# 222  ESTAT:TEPSR_LM411(1.0)  22/10/21 23:00:00    A   T  TOTAL   PC  UK
# 223  ESTAT:TEPSR_LM411(1.0)  22/10/21 23:00:00    A   T  TOTAL   PC  UK
# 224  ESTAT:TEPSR_LM411(1.0)  22/10/21 23:00:00    A   T  TOTAL   PC  UK
# 225  ESTAT:TEPSR_LM411(1.0)  22/10/21 23:00:00    A   T  TOTAL   PC  UK
#
#      TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0           2016       69.7      NaN
# ...

# %%
people_risk_poverty = people_risk_poverty.iloc[:,6:9].rename(columns = {"OBS_VALUE":"Poverty"})

# %%
people_risk_poverty_2015 = people_risk_poverty[people_risk_poverty.TIME_PERIOD == 2015].rename(columns = {'Poverty':'Poverty_risk_2015'}).drop(columns = 'TIME_PERIOD')

# %%
people_risk_poverty_2019 = people_risk_poverty[people_risk_poverty.TIME_PERIOD == 2019].rename(columns = {'Poverty':'Poverty_risk_2019'}).drop(columns = 'TIME_PERIOD')

# %% [markdown]
# ### Variables: people_risk_poverty_2015, people_risk_poverty_2019

# %% [markdown]
# ## The real gross disposable income of households per capita (index = 2008)
#
# The real gross disposable income of households per capita (index = 2008) is calculated as the unadjusted gross disposable income of households and Non-Profit Institutions Serving Households (NPISH) divided by the price deflator (price index) of household final consumption expenditure and by the total resident population. Then the indicator is indexed with base year 2008. The indicator is based on European sector accounts.

# %%
gross_disposable_income = pd.read_csv('/Users/ewawesolowska/Documents/Data_Analytics/Final project/Gross_disposable_income.csv')

# %%
gross_disposable_income
# Out:
#                    DATAFLOW        LAST UPDATE freq     unit direct  \
# 0    ESTAT:TEPSR_WC310(1.0)  22/10/21 11:00:00    A  CP_MNAC   PAID
# 1    ESTAT:TEPSR_WC310(1.0)  22/10/21 11:00:00    A  CP_MNAC   PAID
# 2    ESTAT:TEPSR_WC310(1.0)  22/10/21 11:00:00    A  CP_MNAC   PAID
# 3    ESTAT:TEPSR_WC310(1.0)  22/10/21 11:00:00    A  CP_MNAC   PAID
# 4    ESTAT:TEPSR_WC310(1.0)  22/10/21 11:00:00    A  CP_MNAC   PAID
# ..                      ...                ...  ...      ...    ...
# 525  ESTAT:TEPSR_WC310(1.0)  22/10/21 11:00:00    A  CP_MNAC   PAID
# 526  ESTAT:TEPSR_WC310(1.0)  22/10/21 11:00:00    A  CP_MNAC   PAID
# 527  ESTAT:TEPSR_WC310(1.0)  22/10/21 11:00:00    A  CP_MNAC   PAID
# 528  ESTAT:TEPSR_WC310(1.0)  22/10/21 11:00:00    A  CP_MNAC   PAID
# 529  ESTAT:TEPSR_WC310(1.0)  22/10/21 11:00:00    A  CP_MNAC   PAID
#
#             na_item   sector geo  TIME_PERIOD  OBS_VALUE  OBS_FLAG
# 0    B6G_R_HAB_2008  S14_S15  AT         2005      95.64       NaN
# ...

# %%
gross_disposable_income_2014 = gross_disposable_income[gross_disposable_income.TIME_PERIOD == 2014].rename(columns = {'OBS_VALUE':'gro_disp_inc_2014'}).iloc[:,7:10].drop(columns = 'TIME_PERIOD')

# %%
gross_disposable_income_2019 = gross_disposable_income[gross_disposable_income.TIME_PERIOD == 2019].rename(columns = {'OBS_VALUE':'gro_disp_inc_2019'}).iloc[:,7:10].drop(columns = 'TIME_PERIOD')

# %% [markdown]
# ### Variables: gross_disposable_income_2014, gross_disposable_income_2019

# %% [markdown]
# ## Persons reporting a chronic disease, by disease
# Asthma [ASTHMA]
# Chronic lower respiratory diseases (excluding asthma) [CHR_LW_RES]
# High blood pressure [HBLPR]
# Diabetes [DIAB]
# Chronic depression [DPR_CHR]
#
# Unit of measure: Percentage

# %%
chronic_disease = pd.read_csv('/Users/ewawesolowska/Documents/Data_Analytics/Final project/Chronic_disease.csv')

# %%
chronic_disease
# Out:
#                                   DATAFLOW        LAST UPDATE freq unit  \
# 0    ESTAT:HLTH_EHIS_CD1E$DEFAULTVIEW(1.0)  22/10/21 23:00:00    A   PC
# 1    ESTAT:HLTH_EHIS_CD1E$DEFAULTVIEW(1.0)  22/10/21 23:00:00    A   PC
# 2    ESTAT:HLTH_EHIS_CD1E$DEFAULTVIEW(1.0)  22/10/21 23:00:00    A   PC
# 3    ESTAT:HLTH_EHIS_CD1E$DEFAULTVIEW(1.0)  22/10/21 23:00:00    A   PC
# 4    ESTAT:HLTH_EHIS_CD1E$DEFAULTVIEW(1.0)  22/10/21 23:00:00    A   PC
# ..                                     ...                ...  ...  ...
# 150  ESTAT:HLTH_EHIS_CD1E$DEFAULTVIEW(1.0)  22/10/21 23:00:00    A   PC
# 151  ESTAT:HLTH_EHIS_CD1E$DEFAULTVIEW(1.0)  22/10/21 23:00:00    A   PC
# 152  ESTAT:HLTH_EHIS_CD1E$DEFAULTVIEW(1.0)  22/10/21 23:00:00    A   PC
# 153  ESTAT:HLTH_EHIS_CD1E$DEFAULTVIEW(1.0)  22/10/21 23:00:00    A   PC
# 154  ESTAT:HLTH_EHIS_CD1E$DEFAULTVIEW(1.0)  22/10/21 23:00:00    A   PC
#
#         hlth_pb isced11 sex    age geo  TIME_PERIOD  OBS_VALUE  OBS_FLAG
# ...

# %%
asthma_2019 = chronic_disease[chronic_disease.hlth_pb=='ASTHMA'].iloc[:,8:11].rename(columns = {'OBS_VALUE':'asthma_2019'}).drop(columns = 'TIME_PERIOD')

# %%
CHR_LW_RES_2019 = chronic_disease[chronic_disease.hlth_pb=='CHR_LW_RES'].iloc[:,8:11].rename(columns = {'OBS_VALUE':'CHR_LW_RES_2019'}).drop(columns = 'TIME_PERIOD')

# %%
DIAB_2019 = chronic_disease[chronic_disease.hlth_pb=='DIAB'].iloc[:,8:11].rename(columns = {'OBS_VALUE':'DIAB_2019'}).drop(columns = 'TIME_PERIOD')

# %%
DPR_CHR_2019 = chronic_disease[chronic_disease.hlth_pb=='DPR_CHR'].iloc[:,8:11].rename(columns = {'OBS_VALUE':'DPR_CHR_2019'}).drop(columns = 'TIME_PERIOD')

# %%
HBLPR_2019 = chronic_disease[chronic_disease.hlth_pb=='HBLPR'].iloc[:,8:11].rename(columns = {'OBS_VALUE':'HBLPR_2019'}).drop(columns = 'TIME_PERIOD')

# %% [markdown]
# ### Variables: asthma_2019, CHR_LW_RES_2019, DIAB_2019, DPR_CHR_2019, HBLPR_2019

# %% [markdown]
# ## Daily consumption of fruit and vegetables
#
# Number of portions
#
# 0 portions [0]
#
# From 1 to 4 portions [1-4]
#
# 5 portions or more [GE5]

# %%
fruit = pd.read_csv('/Users/ewawesolowska/Documents/Data_Analytics/Final project/Fruit_per_day.csv')

# %%
fruit
# Out:
#                      DATAFLOW        LAST UPDATE freq unit n_portion  \
# 0   ESTAT:HLTH_EHIS_FV3I(1.0)  22/10/21 23:00:00    A   PC         0
# 1   ESTAT:HLTH_EHIS_FV3I(1.0)  22/10/21 23:00:00    A   PC       1-4
# 2   ESTAT:HLTH_EHIS_FV3I(1.0)  22/10/21 23:00:00    A   PC       GE5
# 3   ESTAT:HLTH_EHIS_FV3I(1.0)  22/10/21 23:00:00    A   PC         0
# 4   ESTAT:HLTH_EHIS_FV3I(1.0)  22/10/21 23:00:00    A   PC       1-4
# ..                        ...                ...  ...  ...       ...
# 88  ESTAT:HLTH_EHIS_FV3I(1.0)  22/10/21 23:00:00    A   PC       1-4
# 89  ESTAT:HLTH_EHIS_FV3I(1.0)  22/10/21 23:00:00    A   PC       GE5
# 90  ESTAT:HLTH_EHIS_FV3I(1.0)  22/10/21 23:00:00    A   PC         0
# 91  ESTAT:HLTH_EHIS_FV3I(1.0)  22/10/21 23:00:00    A   PC       1-4
# 92  ESTAT:HLTH_EHIS_FV3I(1.0)  22/10/21 23:00:00    A   PC       GE5
#
#    quant_inc sex    age geo  TIME_PERIOD  OBS_VALUE  OBS_FLAG
# 0      TOTAL   T  TOTAL  AT         2019       35.8       NaN
# ...

# %%
fruit_0 = fruit[fruit.n_portion == '0'].rename(columns = {'OBS_VALUE':'Fruit_0_day'}).iloc[:,8:11].drop(columns = 'TIME_PERIOD')

# %%
fruit_1_4 = fruit[fruit.n_portion == '1-4'].rename(columns = {'OBS_VALUE':'Fruit_1-4_day'}).iloc[:,8:11].drop(columns = 'TIME_PERIOD')

# %%
fruit_5 = fruit[fruit.n_portion == 'GE5'].rename(columns = {'OBS_VALUE':'Fruit_GE5'}).iloc[:,8:11].drop(columns = 'TIME_PERIOD')

# %% [markdown]
# ### Variables: fruit_0, fruit_1_4, fruit_5

# %% [markdown]
# ## Deaths (total) - csv downloaded, but data not loaded
# https://ec.europa.eu/eurostat/databrowser/view/demo_r_deaths/default/table?lang=en

# %% [markdown]
# ## Life expectancy

# %%
life_exp = pd.read_csv('/Users/ewawesolowska/Downloads/Life_expectancy.csv')

# %%
life_exp
# Out:
#                                   DATAFLOW        LAST UPDATE freq unit sex  \
# 0    ESTAT:DEMO_R_MLIFEXP$DEFAULTVIEW(1.0)  03/06/21 11:00:00    A   YR   T
# 1    ESTAT:DEMO_R_MLIFEXP$DEFAULTVIEW(1.0)  03/06/21 11:00:00    A   YR   T
# 2    ESTAT:DEMO_R_MLIFEXP$DEFAULTVIEW(1.0)  03/06/21 11:00:00    A   YR   T
# 3    ESTAT:DEMO_R_MLIFEXP$DEFAULTVIEW(1.0)  03/06/21 11:00:00    A   YR   T
# 4    ESTAT:DEMO_R_MLIFEXP$DEFAULTVIEW(1.0)  03/06/21 11:00:00    A   YR   T
# ..                                     ...                ...  ...  ...  ..
# 179  ESTAT:DEMO_R_MLIFEXP$DEFAULTVIEW(1.0)  03/06/21 11:00:00    A   YR   T
# 180  ESTAT:DEMO_R_MLIFEXP$DEFAULTVIEW(1.0)  03/06/21 11:00:00    A   YR   T
# 181  ESTAT:DEMO_R_MLIFEXP$DEFAULTVIEW(1.0)  03/06/21 11:00:00    A   YR   T
# 182  ESTAT:DEMO_R_MLIFEXP$DEFAULTVIEW(1.0)  03/06/21 11:00:00    A   YR   T
# 183  ESTAT:DEMO_R_MLIFEXP$DEFAULTVIEW(1.0)  03/06/21 11:00:00    A   YR   T
#
#        age geo  TIME_PERIOD  OBS_VALUE OBS_FLAG
# ...

# %%
life_exp_2015 = life_exp[life_exp.TIME_PERIOD == 2015].rename(columns = {'OBS_VALUE': "life_exp_2015"}).iloc[:,6:9].drop(columns = 'TIME_PERIOD')

# %%
life_exp_2019 = life_exp[life_exp.TIME_PERIOD == 2019].rename(columns = {'OBS_VALUE': "life_exp_2019"}).iloc[:,6:9].drop(columns = 'TIME_PERIOD')

# %% [markdown]
# ### Variables: life_exp_2015, life_exp_2019

# %% [markdown]
# ## Gross domestic product (GDP) at current market prices
# https://ec.europa.eu/eurostat/databrowser/view/nama_10r_2gdp/default/table?lang=en

# %%
GDP = pd.read_csv('/Users/ewawesolowska/Documents/Data_Analytics/Final project/GDP.csv')

# %%
GDP
# Out:
#                                  DATAFLOW        LAST UPDATE freq     unit  \
# 0    ESTAT:NAMA_10R_2GDP$DEFAULTVIEW(1.0)  14/07/21 23:00:00    A  MIO_EUR
# 1    ESTAT:NAMA_10R_2GDP$DEFAULTVIEW(1.0)  14/07/21 23:00:00    A  MIO_EUR
# 2    ESTAT:NAMA_10R_2GDP$DEFAULTVIEW(1.0)  14/07/21 23:00:00    A  MIO_EUR
# 3    ESTAT:NAMA_10R_2GDP$DEFAULTVIEW(1.0)  14/07/21 23:00:00    A  MIO_EUR
# 4    ESTAT:NAMA_10R_2GDP$DEFAULTVIEW(1.0)  14/07/21 23:00:00    A  MIO_EUR
# ..                                    ...                ...  ...      ...
# 327  ESTAT:NAMA_10R_2GDP$DEFAULTVIEW(1.0)  14/07/21 23:00:00    A  MIO_EUR
# 328  ESTAT:NAMA_10R_2GDP$DEFAULTVIEW(1.0)  14/07/21 23:00:00    A  MIO_EUR
# 329  ESTAT:NAMA_10R_2GDP$DEFAULTVIEW(1.0)  14/07/21 23:00:00    A  MIO_EUR
# 330  ESTAT:NAMA_10R_2GDP$DEFAULTVIEW(1.0)  14/07/21 23:00:00    A  MIO_EUR
# 331  ESTAT:NAMA_10R_2GDP$DEFAULTVIEW(1.0)  14/07/21 23:00:00    A  MIO_EUR
#
#     geo  TIME_PERIOD  OBS_VALUE OBS_FLAG
# ...

# %%
GDP_2014 = GDP[GDP.TIME_PERIOD == 2014].rename(columns = {'OBS_VALUE': 'GDP_2014'}).iloc[:,4:7].drop(columns = 'TIME_PERIOD')

# %%
GDP_2019 = GDP[GDP.TIME_PERIOD == 2019].rename(columns = {'OBS_VALUE': 'GDP_2019'}).iloc[:,4:7].drop(columns = 'TIME_PERIOD')

# %% [markdown]
# ### Varilables: GDP_2014, GDP_2019

# %% [markdown]
# ## crude death rate
# https://ec.europa.eu/eurostat/databrowser/view/hlth_cd_acdr2/default/table?lang=en

# %%
crude_death_rate = pd.read_csv('/Users/ewawesolowska/Documents/Data_Analytics/Final project/Crude_death_rate.csv')

# %%
crude_death_rate
# Out:
#                                  DATAFLOW        LAST UPDATE freq unit sex  \
# 0    ESTAT:HLTH_CD_ACDR2$DEFAULTVIEW(1.0)  12/10/21 11:00:00    A   RT   T
# 1    ESTAT:HLTH_CD_ACDR2$DEFAULTVIEW(1.0)  12/10/21 11:00:00    A   RT   T
# 2    ESTAT:HLTH_CD_ACDR2$DEFAULTVIEW(1.0)  12/10/21 11:00:00    A   RT   T
# 3    ESTAT:HLTH_CD_ACDR2$DEFAULTVIEW(1.0)  12/10/21 11:00:00    A   RT   T
# 4    ESTAT:HLTH_CD_ACDR2$DEFAULTVIEW(1.0)  12/10/21 11:00:00    A   RT   T
# ..                                    ...                ...  ...  ...  ..
# 277  ESTAT:HLTH_CD_ACDR2$DEFAULTVIEW(1.0)  12/10/21 11:00:00    A   RT   T
# 278  ESTAT:HLTH_CD_ACDR2$DEFAULTVIEW(1.0)  12/10/21 11:00:00    A   RT   T
# 279  ESTAT:HLTH_CD_ACDR2$DEFAULTVIEW(1.0)  12/10/21 11:00:00    A   RT   T
# 280  ESTAT:HLTH_CD_ACDR2$DEFAULTVIEW(1.0)  12/10/21 11:00:00    A   RT   T
# 281  ESTAT:HLTH_CD_ACDR2$DEFAULTVIEW(1.0)  12/10/21 11:00:00    A   RT   T
#
#        age    icd10 geo  TIME_PERIOD  OBS_VALUE OBS_FLAG
# ...

# %%
crude_death_rate_2014 = crude_death_rate[crude_death_rate.TIME_PERIOD == 2014].rename(columns = {'OBS_VALUE':'cr_death_rt_2014'}).iloc[:,7:10].drop(columns = 'TIME_PERIOD')

# %%
crude_death_rate_2018 = crude_death_rate[crude_death_rate.TIME_PERIOD == 2018].rename(columns = {'OBS_VALUE':'cr_death_rt_2018'}).iloc[:,7:10].drop(columns = 'TIME_PERIOD')

# %% [markdown]
# ### Variables: crude_death_rate_2014, crude_death_rate_2018

# %% [markdown]
# ## Infant mortality rates
# https://ec.europa.eu/eurostat/databrowser/view/demo_minfind/default/table?lang=en

# %%
inf_mort = pd.read_csv('/Users/ewawesolowska/Documents/Data_Analytics/Final project/Infant_mortality.csv')

# %%
inf_mort
# Out:
#                                 DATAFLOW        LAST UPDATE freq unit  \
# 0    ESTAT:DEMO_MINFIND$DEFAULTVIEW(1.0)  19/05/21 11:00:00    A   RT
# 1    ESTAT:DEMO_MINFIND$DEFAULTVIEW(1.0)  19/05/21 11:00:00    A   RT
# 2    ESTAT:DEMO_MINFIND$DEFAULTVIEW(1.0)  19/05/21 11:00:00    A   RT
# 3    ESTAT:DEMO_MINFIND$DEFAULTVIEW(1.0)  19/05/21 11:00:00    A   RT
# 4    ESTAT:DEMO_MINFIND$DEFAULTVIEW(1.0)  19/05/21 11:00:00    A   RT
# ..                                   ...                ...  ...  ...
# 524  ESTAT:DEMO_MINFIND$DEFAULTVIEW(1.0)  19/05/21 11:00:00    A   RT
# 525  ESTAT:DEMO_MINFIND$DEFAULTVIEW(1.0)  19/05/21 11:00:00    A   RT
# 526  ESTAT:DEMO_MINFIND$DEFAULTVIEW(1.0)  19/05/21 11:00:00    A   RT
# 527  ESTAT:DEMO_MINFIND$DEFAULTVIEW(1.0)  19/05/21 11:00:00    A   RT
# 528  ESTAT:DEMO_MINFIND$DEFAULTVIEW(1.0)  19/05/21 11:00:00    A   RT
#
#      indic_de geo  TIME_PERIOD  OBS_VALUE  OBS_FLAG
# 0    INFMORRT  AD         2010        0.0       NaN
# ...

# %%
inf_mort_2014 = inf_mort[inf_mort.TIME_PERIOD == 2014].rename(columns = {'OBS_VALUE':'inf_mort_2014'}).iloc[:,5:8].drop(columns = 'TIME_PERIOD')

# %%
inf_mort_2019 = inf_mort[inf_mort.TIME_PERIOD == 2019].rename(columns = {'OBS_VALUE':'inf_mort_2019'}).iloc[:,5:8].drop(columns = 'TIME_PERIOD')

# %% [markdown]
# ### Variables: inf_mort_2014, inf_mort_2019

# %% [markdown]
# ## Healthy life years
# https://ec.europa.eu/eurostat/databrowser/view/hlth_hlye/default/table?lang=en

# %%
healthy_years = pd.read_csv('/Users/ewawesolowska/Documents/Data_Analytics/Final project/healthy_life_years.csv')

# %%
healthy_years
# Out:
#                              DATAFLOW        LAST UPDATE freq unit sex  \
# 0    ESTAT:HLTH_HLYE$DEFAULTVIEW(1.0)  11/03/21 23:00:00    A   YR   T
# 1    ESTAT:HLTH_HLYE$DEFAULTVIEW(1.0)  11/03/21 23:00:00    A   YR   T
# 2    ESTAT:HLTH_HLYE$DEFAULTVIEW(1.0)  11/03/21 23:00:00    A   YR   T
# 3    ESTAT:HLTH_HLYE$DEFAULTVIEW(1.0)  11/03/21 23:00:00    A   YR   T
# 4    ESTAT:HLTH_HLYE$DEFAULTVIEW(1.0)  11/03/21 23:00:00    A   YR   T
# ..                                ...                ...  ...  ...  ..
# 319  ESTAT:HLTH_HLYE$DEFAULTVIEW(1.0)  11/03/21 23:00:00    A   YR   T
# 320  ESTAT:HLTH_HLYE$DEFAULTVIEW(1.0)  11/03/21 23:00:00    A   YR   T
# 321  ESTAT:HLTH_HLYE$DEFAULTVIEW(1.0)  11/03/21 23:00:00    A   YR   T
# 322  ESTAT:HLTH_HLYE$DEFAULTVIEW(1.0)  11/03/21 23:00:00    A   YR   T
# 323  ESTAT:HLTH_HLYE$DEFAULTVIEW(1.0)  11/03/21 23:00:00    A   YR   T
#
#     indic_he geo  TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0      HLY_0  AT         2010       60.1      NaN
# ...

# %%
healthy_years_2014 = healthy_years[healthy_years.TIME_PERIOD == 2014].rename(columns = {'OBS_VALUE':'healthy_y_2014'}).iloc[:,6:9].drop(columns = 'TIME_PERIOD')

# %%
healthy_years_2019 = healthy_years[healthy_years.TIME_PERIOD == 2019].rename(columns = {'OBS_VALUE':'healthy_y_2019'}).iloc[:,6:9].drop(columns = 'TIME_PERIOD')

# %% [markdown]
# ### Variables: healthy_years_2014, healthy_years_2019

# %% [markdown]
# ## Health care expenditure, unit of measure: euro per inhabitant
# https://ec.europa.eu/eurostat/databrowser/view/hlth_sha11_hp/default/table?lang=en

# %%
health_exp = pd.read_csv('/Users/ewawesolowska/Documents/Data_Analytics/Final project/health_exp.csv')

# %%
health_exp
# Out:
#                      DATAFLOW        LAST UPDATE freq     unit icha11_hp geo  \
# 0    ESTAT:HLTH_SHA11_HP(1.0)  13/10/21 11:00:00    A  EUR_HAB     TOTAL  AT
# 1    ESTAT:HLTH_SHA11_HP(1.0)  13/10/21 11:00:00    A  EUR_HAB     TOTAL  AT
# 2    ESTAT:HLTH_SHA11_HP(1.0)  13/10/21 11:00:00    A  EUR_HAB     TOTAL  AT
# 3    ESTAT:HLTH_SHA11_HP(1.0)  13/10/21 11:00:00    A  EUR_HAB     TOTAL  AT
# 4    ESTAT:HLTH_SHA11_HP(1.0)  13/10/21 11:00:00    A  EUR_HAB     TOTAL  AT
# ..                        ...                ...  ...      ...       ...  ..
# 306  ESTAT:HLTH_SHA11_HP(1.0)  13/10/21 11:00:00    A  EUR_HAB     TOTAL  UK
# 307  ESTAT:HLTH_SHA11_HP(1.0)  13/10/21 11:00:00    A  EUR_HAB     TOTAL  UK
# 308  ESTAT:HLTH_SHA11_HP(1.0)  13/10/21 11:00:00    A  EUR_HAB     TOTAL  UK
# 309  ESTAT:HLTH_SHA11_HP(1.0)  13/10/21 11:00:00    A  EUR_HAB     TOTAL  UK
# 310  ESTAT:HLTH_SHA11_HP(1.0)  13/10/21 11:00:00    A  EUR_HAB     TOTAL  UK
#
#      TIME_PERIOD  OBS_VALUE OBS_FLAG
# ...

# %%
health_exp_2014 = health_exp[health_exp.TIME_PERIOD  == 2014].rename(columns = {'OBS_VALUE':'health_exp_2014'}).iloc[:,5:8].drop(columns = 'TIME_PERIOD')

# %%
health_exp_2019 = health_exp[health_exp.TIME_PERIOD  == 2019].rename(columns = {'OBS_VALUE':'health_exp_2019'}).iloc[:,5:8].drop(columns = 'TIME_PERIOD')

# %% [markdown]
# ### Variables: health_exp_2014, health_exp_2019

# %% [markdown]
# ## Health personnel (excluding nursing and caring professionals) Per hundred thousand inhabitants
# https://ec.europa.eu/eurostat/databrowser/view/HLTH_RS_PRS1__custom_1470555/default/table?lang=en

# %%
personnel = pd.read_csv('/Users/ewawesolowska/Documents/Data_Analytics/Final project/Personnel.csv')

# %%
personnel
# Out:
#                     DATAFLOW        LAST UPDATE freq     unit wstatus isco08  \
# 0    ESTAT:HLTH_RS_PRS1(1.0)  02/07/21 11:00:00    A  P_HTHAB   PRACT  OC221
# 1    ESTAT:HLTH_RS_PRS1(1.0)  02/07/21 11:00:00    A  P_HTHAB   PRACT  OC221
# 2    ESTAT:HLTH_RS_PRS1(1.0)  02/07/21 11:00:00    A  P_HTHAB   PRACT  OC221
# 3    ESTAT:HLTH_RS_PRS1(1.0)  02/07/21 11:00:00    A  P_HTHAB   PRACT  OC221
# 4    ESTAT:HLTH_RS_PRS1(1.0)  02/07/21 11:00:00    A  P_HTHAB   PRACT  OC221
# ..                       ...                ...  ...      ...     ...    ...
# 252  ESTAT:HLTH_RS_PRS1(1.0)  02/07/21 11:00:00    A  P_HTHAB   PRACT  OC221
# 253  ESTAT:HLTH_RS_PRS1(1.0)  02/07/21 11:00:00    A  P_HTHAB   PRACT  OC221
# 254  ESTAT:HLTH_RS_PRS1(1.0)  02/07/21 11:00:00    A  P_HTHAB   PRACT  OC221
# 255  ESTAT:HLTH_RS_PRS1(1.0)  02/07/21 11:00:00    A  P_HTHAB   PRACT  OC221
# 256  ESTAT:HLTH_RS_PRS1(1.0)  02/07/21 11:00:00    A  P_HTHAB   PRACT  OC221
#
#     geo  TIME_PERIOD  OBS_VALUE OBS_FLAG
# ...

# %%
personnel_2014 = personnel[personnel.TIME_PERIOD == 2014].rename(columns = {'OBS_VALUE':'personnel_2014'}).iloc[:,6:9].drop(columns = 'TIME_PERIOD')

# %%
personnel_2018 = personnel[personnel.TIME_PERIOD == 2018].rename(columns = {'OBS_VALUE':'personnel_2018'}).iloc[:,6:9].drop(columns = 'TIME_PERIOD')

# %% [markdown]
# ### Variables: personnel_2014, personnel_2018

# %% [markdown]
# ## Hospital beds Per hundred thousand inhabitants
# https://ec.europa.eu/eurostat/databrowser/view/hlth_rs_bds/default/table?lang=en

# %%
hosp_beds = pd.read_csv('/Users/ewawesolowska/Documents/Data_Analytics/Final project/hospital_beds.csv')

# %%
hosp_beds
# Out:
#                                DATAFLOW        LAST UPDATE freq     unit  \
# 0    ESTAT:HLTH_RS_BDS$DEFAULTVIEW(1.0)  02/07/21 11:00:00    A  P_HTHAB
# 1    ESTAT:HLTH_RS_BDS$DEFAULTVIEW(1.0)  02/07/21 11:00:00    A  P_HTHAB
# 2    ESTAT:HLTH_RS_BDS$DEFAULTVIEW(1.0)  02/07/21 11:00:00    A  P_HTHAB
# 3    ESTAT:HLTH_RS_BDS$DEFAULTVIEW(1.0)  02/07/21 11:00:00    A  P_HTHAB
# 4    ESTAT:HLTH_RS_BDS$DEFAULTVIEW(1.0)  02/07/21 11:00:00    A  P_HTHAB
# ..                                  ...                ...  ...      ...
# 337  ESTAT:HLTH_RS_BDS$DEFAULTVIEW(1.0)  02/07/21 11:00:00    A  P_HTHAB
# 338  ESTAT:HLTH_RS_BDS$DEFAULTVIEW(1.0)  02/07/21 11:00:00    A  P_HTHAB
# 339  ESTAT:HLTH_RS_BDS$DEFAULTVIEW(1.0)  02/07/21 11:00:00    A  P_HTHAB
# 340  ESTAT:HLTH_RS_BDS$DEFAULTVIEW(1.0)  02/07/21 11:00:00    A  P_HTHAB
# 341  ESTAT:HLTH_RS_BDS$DEFAULTVIEW(1.0)  02/07/21 11:00:00    A  P_HTHAB
#
#     facility geo  TIME_PERIOD  OBS_VALUE OBS_FLAG
# ...

# %%
hosp_beds2014 = hosp_beds[hosp_beds.TIME_PERIOD== 2014].rename(columns = {'OBS_VALUE':'hosp_beds2014'}).iloc[:,5:8].drop(columns = 'TIME_PERIOD')

# %%
hosp_beds2018 = hosp_beds[hosp_beds.TIME_PERIOD== 2018].rename(columns = {'OBS_VALUE':'hosp_beds2018'}).iloc[:,5:8].drop(columns = 'TIME_PERIOD')

# %% [markdown]
# ### Variables: hosp_beds2014, hosp_beds2018

# %% [markdown]
# ## Employment rate by sex
# https://ec.europa.eu/eurostat/databrowser/view/tesem010/default/table?lang=en

# %%
unempl2019 = pd.read_csv('/Users/ewawesolowska/Documents/Data_Analytics/Final project/unemployment_2019.csv')

# %%
unempl2019 = unempl2019.iloc[:,7:10].rename(columns = {'OBS_VALUE':'unempl2019'}).drop(columns = 'TIME_PERIOD')

# %% [markdown]
# ### Variable: unempl2019

# %% [markdown]
# ## Households with access to the internet at home
# https://ec.europa.eu/eurostat/databrowser/view/isoc_r_iacc_h/default/table?lang=en

# %%
internet2019 = pd.read_csv('/Users/ewawesolowska/Documents/Data_Analytics/Final project/internet_access2019csv.csv')

# %%
internet2019 = internet2019.iloc[:,4:7].rename(columns = {'OBS_VALUE':'int_access2019'}).drop(columns = 'TIME_PERIOD')

# %% [markdown]
# ### Variables = internet2019

# %% [markdown]
# ## Young people neither in employment nor in education and training
# https://ec.europa.eu/eurostat/databrowser/view/edat_lfse_29/default/table?lang=en

# %%
no_job_no_edu = pd.read_csv('/Users/ewawesolowska/Documents/Data_Analytics/Final project/people_no_job_no_edu.csv')

# %%
no_job_no_edu = no_job_no_edu.iloc[:,9:12].rename(columns = {'OBS_VALUE':'no_job_no_edu'}).drop(columns = 'TIME_PERIOD')

# %% [markdown]
# ### Variables: no_job_no_edu

# %% [markdown]
# ## Mean and median income (in cities, in euro)
# https://ec.europa.eu/eurostat/databrowser/view/ILC_DI17__custom_1504248/default/table?lang=en

# %%
income2019 = pd.read_csv('/Users/ewawesolowska/Documents/Data_Analytics/Final project/income2019.csv')

# %%
income2019 = income2019.iloc[:,8:11].rename(columns = {'OBS_VALUE':'income2019'}).drop(columns = 'TIME_PERIOD')

# %% [markdown]
# ### Variables: income2019

# %% [markdown]
# # Creating health situation before covid

# %%
df_health_list = [obestity_rate_2014, obestity_rate_2019, 
                  asthma_2019, CHR_LW_RES_2019, DIAB_2019, DPR_CHR_2019, HBLPR_2019,
                   fruit_0, fruit_1_4, fruit_5,
                   life_exp_2015, life_exp_2019,
                   crude_death_rate_2014, crude_death_rate_2018,
                   inf_mort_2014, inf_mort_2019,
                   healthy_years_2014, healthy_years_2019]

# %%
df_economy_list = [people_risk_poverty_2015, people_risk_poverty_2019, 
                    gross_disposable_income_2014, gross_disposable_income_2019,
                   GDP_2014, GDP_2019,
                    health_exp_2014, health_exp_2019,
                    personnel_2014, personnel_2018,
                    hosp_beds2014, hosp_beds2018,
                    unempl2019,
                    internet2019,
                    no_job_no_edu,
                    income2019]

# %%
number_of_variables = len(df_health_list) + len(df_economy_list)

# %%
all_variables = df_health_list + df_economy_list

# %%
number_of_variables
# Out:
# 34

# %%
df_all = reduce(lambda  left,right: pd.merge(left,right,on=['geo'],
                                            how='outer'), all_variables)

# %%
df_all
# Out:
#            geo  Obesity_2014  Obesity_2019  asthma_2019  CHR_LW_RES_2019  \
# 0           AT          48.0          52.2          4.3              4.6
# 1           BE          49.3          50.2          5.8              4.0
# 2           BG          54.0          54.9          2.2              3.2
# 3           CY          48.3          49.8          4.0              2.9
# 4           CZ          56.8          60.0          4.6              2.2
# 5           DE          52.1          53.5          8.0              5.9
# 6           DK          47.7          50.4          7.2              3.4
# 7           EE          53.9          56.7          4.1              2.5
# 8           EL          56.7          57.6          3.3              1.9
# 9           ES          52.4          53.7          4.1              2.7
# 10   EU27_2020          51.1          52.7          5.7              4.3
# 11        EU28          51.6           NaN          NaN              NaN
# ...

# %% [markdown]
# ## Droping rows that have at least 70 % na

# %%
df_all.shape[1]
# Out:
# 35

# %%
df_all.isnull().sum()
# Out:
# geo                   0
# Obesity_2014         25
# Obesity_2019         27
# asthma_2019          27
# CHR_LW_RES_2019      27
# DIAB_2019            27
# DPR_CHR_2019         27
# HBLPR_2019           27
# Fruit_0_day          27
# Fruit_1-4_day        27
# Fruit_GE5            27
# life_exp_2015        21
# life_exp_2019        22
# cr_death_rt_2014     22
# cr_death_rt_2018     25
# inf_mort_2014         5
# inf_mort_2019        13
# healthy_y_2014       25
# healthy_y_2019       28
# Poverty_risk_2015    18
# Poverty_risk_2019    21
# gro_disp_inc_2014    24
# gro_disp_inc_2019    26
# GDP_2014             25
# GDP_2019             25
# health_exp_2014      20
# health_exp_2019      29
# personnel_2014       29
# personnel_2018       30
# hosp_beds2014        20
# hosp_beds2018        20
# unempl2019           22
# int_access2019       20
# no_job_no_edu        19
# income2019           19
# dtype: int64

# %% [markdown]
# thresh=N requires that a column has at least N non-NaNs to survive

# %%
threshold = 60.0
min_count =  int(((100-threshold)/100)*df_all.shape[1] + 1)
df_all = df_all.dropna( axis=0, thresh=min_count)

# %%
df_all.shape
# Out:
# (36, 35)

# %%
df_all
# Out:
#           geo  Obesity_2014  Obesity_2019  asthma_2019  CHR_LW_RES_2019  \
# 0          AT          48.0          52.2          4.3              4.6
# 1          BE          49.3          50.2          5.8              4.0
# 2          BG          54.0          54.9          2.2              3.2
# 3          CY          48.3          49.8          4.0              2.9
# 4          CZ          56.8          60.0          4.6              2.2
# 5          DE          52.1          53.5          8.0              5.9
# 6          DK          47.7          50.4          7.2              3.4
# 7          EE          53.9          56.7          4.1              2.5
# 8          EL          56.7          57.6          3.3              1.9
# 9          ES          52.4          53.7          4.1              2.7
# 10  EU27_2020          51.1          52.7          5.7              4.3
# 12         FI          54.7          59.0          9.4              3.3
# ...

# %% [markdown]
# Non-EU countries with nans will be removed

# %%
df_all.drop(df_all[df_all.geo == 'CH'].index, inplace = True)

df_all.drop(df_all[df_all.geo == 'IS'].index, inplace = True)

df_all.drop(df_all[df_all.geo == 'RS'].index, inplace = True)
# Out:
# /Users/ewawesolowska/opt/anaconda3/envs/DataAnalytics/lib/python3.7/site-packages/pandas/core/frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_all.drop(df_all[df_all.geo == 'ME'].index, inplace = True)

df_all.drop(df_all[df_all.geo == 'MK'].index, inplace = True)

# %%
df_all.drop(df_all[df_all.geo == 'UK'].index, inplace = True)

# %%
df_all.drop(df_all[df_all.geo == 'NO'].index, inplace = True)

# %%
df_all.drop(df_all[df_all.geo == 'TR'].index, inplace = True)

# %%
df_all
# Out:
#           geo  Obesity_2014  Obesity_2019  asthma_2019  CHR_LW_RES_2019  \
# 0          AT          48.0          52.2          4.3              4.6
# 1          BE          49.3          50.2          5.8              4.0
# 2          BG          54.0          54.9          2.2              3.2
# 3          CY          48.3          49.8          4.0              2.9
# 4          CZ          56.8          60.0          4.6              2.2
# 5          DE          52.1          53.5          8.0              5.9
# 6          DK          47.7          50.4          7.2              3.4
# 7          EE          53.9          56.7          4.1              2.5
# 8          EL          56.7          57.6          3.3              1.9
# 9          ES          52.4          53.7          4.1              2.7
# 10  EU27_2020          51.1          52.7          5.7              4.3
# 12         FI          54.7          59.0          9.4              3.3
# ...

# %%
df_all.isnull().sum()
# Out:
# geo                  0
# Obesity_2014         0
# Obesity_2019         0
# asthma_2019          0
# CHR_LW_RES_2019      0
# DIAB_2019            0
# DPR_CHR_2019         0
# HBLPR_2019           0
# Fruit_0_day          0
# Fruit_1-4_day        0
# Fruit_GE5            0
# life_exp_2015        1
# life_exp_2019        1
# cr_death_rt_2014     0
# cr_death_rt_2018     2
# inf_mort_2014        0
# inf_mort_2019        0
# healthy_y_2014       0
# healthy_y_2019       0
# Poverty_risk_2015    0
# Poverty_risk_2019    0
# gro_disp_inc_2014    0
# gro_disp_inc_2019    1
# GDP_2014             1
# GDP_2019             0
# health_exp_2014      0
# health_exp_2019      3
# personnel_2014       5
# personnel_2018       7
# hosp_beds2014        0
# hosp_beds2018        0
# unempl2019           0
# int_access2019       1
# no_job_no_edu        0
# income2019           0
# dtype: int64

# %% [markdown]
# The data has only a few nans. They will be handled in the next stage.

# %%
df_all.reset_index(drop=True, inplace = True)

# %%
df_all
# Out:
#           geo  Obesity_2014  Obesity_2019  asthma_2019  CHR_LW_RES_2019  \
# 0          AT          48.0          52.2          4.3              4.6
# 1          BE          49.3          50.2          5.8              4.0
# 2          BG          54.0          54.9          2.2              3.2
# 3          CY          48.3          49.8          4.0              2.9
# 4          CZ          56.8          60.0          4.6              2.2
# 5          DE          52.1          53.5          8.0              5.9
# 6          DK          47.7          50.4          7.2              3.4
# 7          EE          53.9          56.7          4.1              2.5
# 8          EL          56.7          57.6          3.3              1.9
# 9          ES          52.4          53.7          4.1              2.7
# 10  EU27_2020          51.1          52.7          5.7              4.3
# 11         FI          54.7          59.0          9.4              3.3
# ...

# %%
df_all.to_csv('all_variables_dataframe',index=False)

# %% [markdown]
# # Target data: excess deaths

# %% [markdown]
# source: https://elifesciences.org/articles/69336#table1

# %%
excess_deaths = pd.read_html('https://elifesciences.org/articles/69336#table1')

# %%
excess_deaths = excess_deaths[0]

# %%
excess_deaths
# Out:
#             Country    Data until Type  Official  Excess      std     z  \
# 0           Albania  Mar 31, 2021    m      2200    9300     ±810  11.4
# 1           Andorra  Dec 31, 2020    m        80      80      ±30   3.1
# 2         Argentina  Dec 31, 2020    m     43000   41000     ±nan   NaN
# 3           Armenia  Apr 30, 2021    m      4100    8300     ±840  10.0
# 4             Aruba  Dec 31, 2020    m        50      50      ±30   1.5
# ..              ...           ...  ...       ...     ...      ...   ...
# 98          Ukraine  Apr 30, 2021    m     44000   81000  ±13,000   6.4
# 99   United Kingdom  Jun 13, 2021    w    130000  110000   ±9,200  11.9
# 100   United States  Jun 06, 2021    w    590000  640000  ±16,000  38.9
# 101         Uruguay  Dec 31, 2020    m       170  −2,200     ±710   3.2
# 102      Uzbekistan  Mar 31, 2021    m       630   20000   ±3,900   5.0
#
#     Undercount Per 100k Increase
# 0          4.2      320       43
# 1          1.0      110       25
# ...

# %%
EU_countries = ['Austria','Belgium','Bulgaria','Cyprus','Czechia','Germany','Denmark','Estonia','Greece','Spain', 'EU27_2020', 'Finland','France',
 'Croatia', 'Hungary','Ireland','Italy', 'Lithuania','Luxembourg','Latvia','Malta','Netherlands',
 'Poland','Portugal','Romania', 'Sweden','Slovenia','Slovakia']

# %%
excess_deaths_EU = excess_deaths[excess_deaths.Country.isin(EU_countries)]

# %%
excess_deaths_EU.reset_index(drop=True, inplace = True)

# %%
excess_deaths_EU
# Out:
#         Country    Data until Type  Official  Excess      std     z  \
# 0       Austria  Jun 13, 2021    w     10000    9800   ±1,400   7.0
# 1       Belgium  Jun 13, 2021    w     25000   16000   ±1,800   8.7
# 2      Bulgaria  Jun 20, 2021    w     18000   32000   ±1,800  17.5
# 3       Croatia  May 30, 2021    w      8000    8800   ±1,000   8.8
# 4        Cyprus  May 09, 2021    w       330     340     ±160   2.1
# 5       Czechia  May 23, 2021    w     30000   35000   ±1,800  18.8
# 6       Denmark  Jun 20, 2021    w      2500    −630     ±610   1.0
# 7       Estonia  Jun 27, 2021    w      1300    1800     ±300   6.0
# 8       Finland  Jun 13, 2021    w       960     410     ±680   0.6
# 9        France  Jun 13, 2021    w    110000   72000   ±8,000   8.9
# 10      Germany  Jun 20, 2021    w     90000   39000  ±17,000   2.3
# 11       Greece  May 02, 2021    w     10000    7500   ±2,000   3.8
# 12      Hungary  May 30, 2021    w     30000   24000   ±2,300  10.2
# ...

# %%
excess_deaths_EU.to_csv('excess_deaths_EU',index=False)

# %% [markdown]
# # Master dataframe

# %%
df_master = df_all

# %%
df_master['Country'] = EU_countries
# Out:
# /Users/ewawesolowska/opt/anaconda3/envs/DataAnalytics/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_master.columns
# Out:
# Index(['geo', 'Obesity_2014', 'Obesity_2019', 'asthma_2019', 'CHR_LW_RES_2019',
#        'DIAB_2019', 'DPR_CHR_2019', 'HBLPR_2019', 'Fruit_0_day',
#        'Fruit_1-4_day', 'Fruit_GE5', 'life_exp_2015', 'life_exp_2019',
#        'cr_death_rt_2014', 'cr_death_rt_2018', 'inf_mort_2014',
#        'inf_mort_2019', 'healthy_y_2014', 'healthy_y_2019',
#        'Poverty_risk_2015', 'Poverty_risk_2019', 'gro_disp_inc_2014',
#        'gro_disp_inc_2019', 'GDP_2014', 'GDP_2019', 'health_exp_2014',
#        'health_exp_2019', 'personnel_2014', 'personnel_2018', 'hosp_beds2014',
#        'hosp_beds2018', 'unempl2019', 'int_access2019', 'no_job_no_edu',
#        'income2019', 'Country'],
#       dtype='object')

# %%
df_master[['geo', 'Country']]
# Out:
#           geo      Country
# 0          AT      Austria
# 1          BE      Belgium
# 2          BG     Bulgaria
# 3          CY       Cyprus
# 4          CZ      Czechia
# 5          DE      Germany
# 6          DK      Denmark
# 7          EE      Estonia
# 8          EL       Greece
# 9          ES        Spain
# 10  EU27_2020    EU27_2020
# 12         FI      Finland
# 13         FR       France
# 14         HR      Croatia
# 15         HU      Hungary
# 16         IE      Ireland
# 18         IT        Italy
# 19         LT    Lithuania
# 20         LU   Luxembourg
# 21         LV       Latvia
# 22         MT        Malta
# 23         NL  Netherlands
# 25         PL       Poland
# 26         PT     Portugal
# 27         RO      Romania
# 28         SE       Sweden
# 29         SI     Slovenia
# 30         SK     Slovakia

# %%
df_master_final = pd.merge(df_master, excess_deaths_EU, how='left', on='Country')

# %%
df_master_final.shape
# Out:
# (28, 45)

# %%
df_master.shape
# Out:
# (28, 36)

# %%
excess_deaths_EU.shape
# Out:
# (27, 10)

# %%
df_master_final.to_csv('df_master_final',index=False)

# %%
df_master_final
# Out:
#           geo  Obesity_2014  Obesity_2019  asthma_2019  CHR_LW_RES_2019  \
# 0          AT          48.0          52.2          4.3              4.6
# 1          BE          49.3          50.2          5.8              4.0
# 2          BG          54.0          54.9          2.2              3.2
# 3          CY          48.3          49.8          4.0              2.9
# 4          CZ          56.8          60.0          4.6              2.2
# 5          DE          52.1          53.5          8.0              5.9
# 6          DK          47.7          50.4          7.2              3.4
# 7          EE          53.9          56.7          4.1              2.5
# 8          EL          56.7          57.6          3.3              1.9
# 9          ES          52.4          53.7          4.1              2.7
# 10  EU27_2020          51.1          52.7          5.7              4.3
# 11         FI          54.7          59.0          9.4              3.3
# ...
